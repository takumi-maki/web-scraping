# %%
from assets import models
import pandas as pd

from assets.database import db_session

# %%
df = pd.read_csv('assets/data.csv')

# %%
df.head()
# Out:
#         date  subscribers  reviews
# 0  2019/1/17         2671      194
# 1  2019/1/18         2671      195
# 2  2019/1/19         2674      197
# 3  2019/1/20         2685      199
# 4  2019/1/21         2695      199

# %%
df.iloc[0, 0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
date = datetime.datetime.strptime(df.iloc[0, 0], '%Y/%m/%d').date()
date
# Out:
# datetime.date(2019, 1, 17)

# %%
for index, _df in df.iterrows():
    #date型への変換
    date = datetime.datetime.strptime(_df['date'], '%Y/%m/%d').date()
    row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
    db_session.add(row)
db_session.commit()
# Out:
# 2021-06-24 17:03:42,200 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-06-24 17:03:42,208 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,209 INFO sqlalchemy.engine.Engine [generated in 0.00094s] ('2019-01-17', 2671, 194, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,210 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,211 INFO sqlalchemy.engine.Engine [cached since 0.00305s ago] ('2019-01-18', 2671, 195, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,211 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,212 INFO sqlalchemy.engine.Engine [cached since 0.004435s ago] ('2019-01-19', 2674, 197, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,213 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,214 INFO sqlalchemy.engine.Engine [cached since 0.005795s ago] ('2019-01-20', 2685, 199, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,214 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,215 INFO sqlalchemy.engine.Engine [cached since 0.00703s ago] ('2019-01-21', 2695, 199, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,216 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,216 INFO sqlalchemy.engine.Engine [cached since 0.008317s ago] ('2019-01-22', 2701, 200, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,217 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,217 INFO sqlalchemy.engine.Engine [cached since 0.009527s ago] ('2019-01-23', 2710, 200, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,218 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,219 INFO sqlalchemy.engine.Engine [cached since 0.0113s ago] ('2019-01-24', 2718, 201, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,221 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,221 INFO sqlalchemy.engine.Engine [cached since 0.01359s ago] ('2019-01-25', 2722, 201, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,223 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,223 INFO sqlalchemy.engine.Engine [cached since 0.01543s ago] ('2019-01-26', 2725, 201, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,224 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,225 INFO sqlalchemy.engine.Engine [cached since 0.01709s ago] ('2019-01-27', 2734, 202, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,226 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,227 INFO sqlalchemy.engine.Engine [cached since 0.01906s ago] ('2019-01-28', 2753, 204, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,228 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,228 INFO sqlalchemy.engine.Engine [cached since 0.02061s ago] ('2019-01-29', 2773, 206, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,229 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,230 INFO sqlalchemy.engine.Engine [cached since 0.02219s ago] ('2019-01-30', 2785, 208, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,231 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,232 INFO sqlalchemy.engine.Engine [cached since 0.02388s ago] ('2019-01-31', 2803, 210, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,233 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,233 INFO sqlalchemy.engine.Engine [cached since 0.02563s ago] ('2019-02-01', 2845, 211, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,234 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,235 INFO sqlalchemy.engine.Engine [cached since 0.02729s ago] ('2019-02-02', 2847, 213, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,236 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,237 INFO sqlalchemy.engine.Engine [cached since 0.02925s ago] ('2019-02-03', 2847, 213, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,238 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,239 INFO sqlalchemy.engine.Engine [cached since 0.03102s ago] ('2019-02-04', 2851, 217, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,240 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,241 INFO sqlalchemy.engine.Engine [cached since 0.03281s ago] ('2019-02-05', 2852, 218, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,241 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,242 INFO sqlalchemy.engine.Engine [cached since 0.03406s ago] ('2019-02-06', 2857, 219, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,243 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,243 INFO sqlalchemy.engine.Engine [cached since 0.03545s ago] ('2019-02-07', 2861, 220, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,244 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,245 INFO sqlalchemy.engine.Engine [cached since 0.03673s ago] ('2019-02-08', 2865, 222, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,245 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,246 INFO sqlalchemy.engine.Engine [cached since 0.03783s ago] ('2019-02-09', 2870, 224, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,246 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,247 INFO sqlalchemy.engine.Engine [cached since 0.0391s ago] ('2019-02-10', 2875, 224, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,248 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,248 INFO sqlalchemy.engine.Engine [cached since 0.04059s ago] ('2019-02-11', 2892, 227, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,250 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,251 INFO sqlalchemy.engine.Engine [cached since 0.04278s ago] ('2019-02-12', 2906, 229, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,252 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,252 INFO sqlalchemy.engine.Engine [cached since 0.04457s ago] ('2019-02-13', 2919, 229, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,254 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,255 INFO sqlalchemy.engine.Engine [cached since 0.04685s ago] ('2019-02-14', 2942, 231, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,256 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,256 INFO sqlalchemy.engine.Engine [cached since 0.04855s ago] ('2019-02-15', 2974, 232, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,257 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,258 INFO sqlalchemy.engine.Engine [cached since 0.04992s ago] ('2019-02-16', 2977, 234, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,258 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,259 INFO sqlalchemy.engine.Engine [cached since 0.05118s ago] ('2019-02-17', 2978, 234, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,260 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,261 INFO sqlalchemy.engine.Engine [cached since 0.0527s ago] ('2019-02-18', 2981, 234, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,262 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,262 INFO sqlalchemy.engine.Engine [cached since 0.05423s ago] ('2019-02-19', 2983, 234, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,263 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,263 INFO sqlalchemy.engine.Engine [cached since 0.05543s ago] ('2019-02-20', 2984, 237, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,264 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,264 INFO sqlalchemy.engine.Engine [cached since 0.05659s ago] ('2019-02-21', 2987, 239, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,265 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,266 INFO sqlalchemy.engine.Engine [cached since 0.0581s ago] ('2019-02-22', 2989, 239, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,267 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,267 INFO sqlalchemy.engine.Engine [cached since 0.05963s ago] ('2019-02-23', 2993, 241, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,269 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,270 INFO sqlalchemy.engine.Engine [cached since 0.06186s ago] ('2019-02-24', 2995, 241, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,271 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,272 INFO sqlalchemy.engine.Engine [cached since 0.06406s ago] ('2019-02-25', 3009, 241, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,273 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,274 INFO sqlalchemy.engine.Engine [cached since 0.06599s ago] ('2019-02-26', 3014, 243, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,275 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,276 INFO sqlalchemy.engine.Engine [cached since 0.06772s ago] ('2019-02-27', 3023, 243, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,277 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,278 INFO sqlalchemy.engine.Engine [cached since 0.06974s ago] ('2019-02-28', 3031, 243, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,279 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,279 INFO sqlalchemy.engine.Engine [cached since 0.07147s ago] ('2019-03-01', 3052, 244, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,280 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,281 INFO sqlalchemy.engine.Engine [cached since 0.07313s ago] ('2019-03-02', 3060, 245, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,282 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,283 INFO sqlalchemy.engine.Engine [cached since 0.07536s ago] ('2019-03-03', 3062, 246, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,284 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,285 INFO sqlalchemy.engine.Engine [cached since 0.07697s ago] ('2019-03-04', 3063, 249, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,286 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,287 INFO sqlalchemy.engine.Engine [cached since 0.07873s ago] ('2019-03-05', 3066, 252, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,288 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,288 INFO sqlalchemy.engine.Engine [cached since 0.08053s ago] ('2019-03-06', 3071, 254, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,289 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,290 INFO sqlalchemy.engine.Engine [cached since 0.08198s ago] ('2019-03-07', 3074, 255, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,291 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,291 INFO sqlalchemy.engine.Engine [cached since 0.08328s ago] ('2019-03-08', 3076, 256, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,292 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,292 INFO sqlalchemy.engine.Engine [cached since 0.08464s ago] ('2019-03-09', 3077, 258, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,293 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,294 INFO sqlalchemy.engine.Engine [cached since 0.08599s ago] ('2019-03-10', 3080, 258, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,295 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,295 INFO sqlalchemy.engine.Engine [cached since 0.08734s ago] ('2019-03-11', 3087, 261, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,296 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,297 INFO sqlalchemy.engine.Engine [cached since 0.0888s ago] ('2019-03-12', 3089, 261, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,298 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,299 INFO sqlalchemy.engine.Engine [cached since 0.0907s ago] ('2019-03-13', 3093, 262, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,300 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,301 INFO sqlalchemy.engine.Engine [cached since 0.09343s ago] ('2019-03-14', 3098, 262, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,302 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,303 INFO sqlalchemy.engine.Engine [cached since 0.09526s ago] ('2019-03-15', 3104, 262, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,304 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,305 INFO sqlalchemy.engine.Engine [cached since 0.09693s ago] ('2019-03-16', 3112, 262, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,306 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,307 INFO sqlalchemy.engine.Engine [cached since 0.09875s ago] ('2019-03-17', 3120, 262, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,308 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,308 INFO sqlalchemy.engine.Engine [cached since 0.1003s ago] ('2019-03-18', 3131, 265, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,309 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,310 INFO sqlalchemy.engine.Engine [cached since 0.1022s ago] ('2019-03-19', 3142, 266, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,311 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,312 INFO sqlalchemy.engine.Engine [cached since 0.1037s ago] ('2019-03-20', 3162, 266, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,312 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,313 INFO sqlalchemy.engine.Engine [cached since 0.1055s ago] ('2019-03-21', 3173, 268, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,315 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,315 INFO sqlalchemy.engine.Engine [cached since 0.1075s ago] ('2019-03-22', 3180, 269, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,316 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,317 INFO sqlalchemy.engine.Engine [cached since 0.1088s ago] ('2019-03-23', 3187, 271, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,317 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,318 INFO sqlalchemy.engine.Engine [cached since 0.1099s ago] ('2019-03-24', 3189, 271, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,319 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,319 INFO sqlalchemy.engine.Engine [cached since 0.1112s ago] ('2019-03-25', 3196, 274, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,320 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,320 INFO sqlalchemy.engine.Engine [cached since 0.1123s ago] ('2019-03-26', 3212, 274, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,321 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,321 INFO sqlalchemy.engine.Engine [cached since 0.1135s ago] ('2019-03-27', 3220, 274, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,322 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,323 INFO sqlalchemy.engine.Engine [cached since 0.1148s ago] ('2019-03-28', 3226, 275, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,323 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,324 INFO sqlalchemy.engine.Engine [cached since 0.116s ago] ('2019-03-29', 3241, 275, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,324 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,325 INFO sqlalchemy.engine.Engine [cached since 0.1171s ago] ('2019-03-30', 3253, 278, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,326 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,326 INFO sqlalchemy.engine.Engine [cached since 0.1183s ago] ('2019-03-31', 3255, 278, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,327 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,327 INFO sqlalchemy.engine.Engine [cached since 0.1195s ago] ('2019-04-01', 3258, 280, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,328 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,329 INFO sqlalchemy.engine.Engine [cached since 0.1209s ago] ('2019-04-02', 3262, 282, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,330 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,331 INFO sqlalchemy.engine.Engine [cached since 0.1235s ago] ('2019-04-03', 3264, 282, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,333 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,334 INFO sqlalchemy.engine.Engine [cached since 0.1257s ago] ('2019-04-04', 3272, 282, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,334 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,335 INFO sqlalchemy.engine.Engine [cached since 0.1269s ago] ('2019-04-05', 3275, 284, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,336 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,336 INFO sqlalchemy.engine.Engine [cached since 0.1283s ago] ('2019-04-06', 3276, 287, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,337 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,337 INFO sqlalchemy.engine.Engine [cached since 0.1295s ago] ('2019-04-07', 3279, 289, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,338 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,339 INFO sqlalchemy.engine.Engine [cached since 0.1307s ago] ('2019-04-08', 3285, 289, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,340 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,340 INFO sqlalchemy.engine.Engine [cached since 0.1322s ago] ('2019-04-09', 3300, 291, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,341 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,341 INFO sqlalchemy.engine.Engine [cached since 0.1335s ago] ('2019-04-10', 3306, 293, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,342 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,342 INFO sqlalchemy.engine.Engine [cached since 0.1347s ago] ('2019-04-11', 3312, 295, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,343 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,344 INFO sqlalchemy.engine.Engine [cached since 0.1359s ago] ('2019-04-12', 3319, 295, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,344 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,345 INFO sqlalchemy.engine.Engine [cached since 0.1372s ago] ('2019-04-13', 3324, 295, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,346 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,346 INFO sqlalchemy.engine.Engine [cached since 0.1382s ago] ('2019-04-14', 3325, 297, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,347 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,348 INFO sqlalchemy.engine.Engine [cached since 0.1397s ago] ('2019-04-15', 3329, 298, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,349 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,350 INFO sqlalchemy.engine.Engine [cached since 0.1418s ago] ('2019-04-16', 3331, 299, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,351 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,352 INFO sqlalchemy.engine.Engine [cached since 0.1438s ago] ('2019-04-17', 3332, 299, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,353 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,353 INFO sqlalchemy.engine.Engine [cached since 0.1452s ago] ('2019-04-18', 3333, 299, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,354 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,354 INFO sqlalchemy.engine.Engine [cached since 0.1464s ago] ('2019-04-19', 3336, 299, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,355 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,355 INFO sqlalchemy.engine.Engine [cached since 0.1475s ago] ('2019-04-20', 3339, 299, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,356 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,356 INFO sqlalchemy.engine.Engine [cached since 0.1487s ago] ('2019-04-21', 3343, 300, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,357 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,358 INFO sqlalchemy.engine.Engine [cached since 0.1498s ago] ('2019-04-22', 3349, 302, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,358 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,359 INFO sqlalchemy.engine.Engine [cached since 0.1509s ago] ('2019-04-23', 3357, 303, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,360 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,360 INFO sqlalchemy.engine.Engine [cached since 0.1522s ago] ('2019-04-24', 3370, 303, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,361 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,361 INFO sqlalchemy.engine.Engine [cached since 0.1533s ago] ('2019-04-25', 3388, 304, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,362 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,362 INFO sqlalchemy.engine.Engine [cached since 0.1544s ago] ('2019-04-26', 3412, 304, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,363 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,364 INFO sqlalchemy.engine.Engine [cached since 0.1558s ago] ('2019-04-27', 3437, 305, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,364 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,365 INFO sqlalchemy.engine.Engine [cached since 0.1574s ago] ('2019-04-28', 3439, 305, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,366 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,367 INFO sqlalchemy.engine.Engine [cached since 0.1594s ago] ('2019-04-29', 3440, 308, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,368 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,368 INFO sqlalchemy.engine.Engine [cached since 0.1606s ago] ('2019-04-30', 3447, 309, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,369 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,370 INFO sqlalchemy.engine.Engine [cached since 0.162s ago] ('2019-05-01', 3466, 310, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,371 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,372 INFO sqlalchemy.engine.Engine [cached since 0.1639s ago] ('2019-05-02', 3481, 311, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,373 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,373 INFO sqlalchemy.engine.Engine [cached since 0.1652s ago] ('2019-05-03', 3504, 314, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,374 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,374 INFO sqlalchemy.engine.Engine [cached since 0.1663s ago] ('2019-05-04', 3522, 317, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,375 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,375 INFO sqlalchemy.engine.Engine [cached since 0.1675s ago] ('2019-05-05', 3527, 322, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,376 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,377 INFO sqlalchemy.engine.Engine [cached since 0.1688s ago] ('2019-05-06', 3533, 324, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,377 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,378 INFO sqlalchemy.engine.Engine [cached since 0.1699s ago] ('2019-05-07', 3543, 327, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,378 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,379 INFO sqlalchemy.engine.Engine [cached since 0.1711s ago] ('2019-05-08', 3546, 328, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,380 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,380 INFO sqlalchemy.engine.Engine [cached since 0.1724s ago] ('2019-05-09', 3555, 330, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,381 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,382 INFO sqlalchemy.engine.Engine [cached since 0.174s ago] ('2019-05-10', 3566, 332, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,383 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,384 INFO sqlalchemy.engine.Engine [cached since 0.1759s ago] ('2019-05-11', 3583, 334, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,384 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,385 INFO sqlalchemy.engine.Engine [cached since 0.1771s ago] ('2019-05-12', 3594, 335, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,386 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,386 INFO sqlalchemy.engine.Engine [cached since 0.1783s ago] ('2019-05-13', 3614, 338, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,387 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,387 INFO sqlalchemy.engine.Engine [cached since 0.1796s ago] ('2019-05-14', 3633, 340, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,388 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,389 INFO sqlalchemy.engine.Engine [cached since 0.1809s ago] ('2019-05-15', 3647, 344, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,390 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,390 INFO sqlalchemy.engine.Engine [cached since 0.1826s ago] ('2019-05-16', 3648, 349, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,391 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,392 INFO sqlalchemy.engine.Engine [cached since 0.184s ago] ('2019-05-17', 3649, 349, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,393 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,393 INFO sqlalchemy.engine.Engine [cached since 0.1853s ago] ('2019-05-18', 3651, 351, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,394 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,394 INFO sqlalchemy.engine.Engine [cached since 0.1867s ago] ('2019-05-19', 3654, 351, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,395 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,396 INFO sqlalchemy.engine.Engine [cached since 0.188s ago] ('2019-05-20', 3658, 354, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,397 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,398 INFO sqlalchemy.engine.Engine [cached since 0.19s ago] ('2019-05-21', 3671, 354, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,399 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,399 INFO sqlalchemy.engine.Engine [cached since 0.1915s ago] ('2019-05-22', 3675, 359, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,400 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,400 INFO sqlalchemy.engine.Engine [cached since 0.1927s ago] ('2019-05-23', 3681, 359, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,401 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,402 INFO sqlalchemy.engine.Engine [cached since 0.1939s ago] ('2019-05-24', 3694, 361, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,402 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,403 INFO sqlalchemy.engine.Engine [cached since 0.1951s ago] ('2019-05-25', 3699, 361, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,404 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,404 INFO sqlalchemy.engine.Engine [cached since 0.1962s ago] ('2019-05-26', 3711, 364, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,405 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,405 INFO sqlalchemy.engine.Engine [cached since 0.1976s ago] ('2019-05-27', 3722, 368, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,406 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,407 INFO sqlalchemy.engine.Engine [cached since 0.1988s ago] ('2019-05-28', 3734, 373, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,407 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,408 INFO sqlalchemy.engine.Engine [cached since 0.2001s ago] ('2019-05-29', 3766, 374, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,409 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,409 INFO sqlalchemy.engine.Engine [cached since 0.2017s ago] ('2019-05-30', 3781, 375, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,411 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,411 INFO sqlalchemy.engine.Engine [cached since 0.2034s ago] ('2019-05-31', 3784, 375, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,412 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,412 INFO sqlalchemy.engine.Engine [cached since 0.2046s ago] ('2019-06-01', 3789, 378, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,413 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,414 INFO sqlalchemy.engine.Engine [cached since 0.2058s ago] ('2019-06-02', 3790, 379, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,414 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,415 INFO sqlalchemy.engine.Engine [cached since 0.2074s ago] ('2019-06-03', 3793, 380, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,416 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,417 INFO sqlalchemy.engine.Engine [cached since 0.2094s ago] ('2019-06-04', 3795, 383, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,418 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,419 INFO sqlalchemy.engine.Engine [cached since 0.2107s ago] ('2019-06-05', 3808, 385, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,419 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,420 INFO sqlalchemy.engine.Engine [cached since 0.2119s ago] ('2019-06-06', 3830, 386, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,420 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,421 INFO sqlalchemy.engine.Engine [cached since 0.2131s ago] ('2019-06-07', 3843, 387, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,422 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,422 INFO sqlalchemy.engine.Engine [cached since 0.2142s ago] ('2019-06-08', 3857, 390, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,423 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,423 INFO sqlalchemy.engine.Engine [cached since 0.2153s ago] ('2019-06-09', 3870, 394, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,424 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,424 INFO sqlalchemy.engine.Engine [cached since 0.2165s ago] ('2019-06-10', 3895, 395, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,425 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,426 INFO sqlalchemy.engine.Engine [cached since 0.2179s ago] ('2019-06-11', 3919, 397, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,427 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,427 INFO sqlalchemy.engine.Engine [cached since 0.2195s ago] ('2019-06-12', 3942, 399, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,428 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,428 INFO sqlalchemy.engine.Engine [cached since 0.2207s ago] ('2019-06-13', 3983, 402, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,430 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,430 INFO sqlalchemy.engine.Engine [cached since 0.2225s ago] ('2019-06-14', 4022, 404, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,432 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,432 INFO sqlalchemy.engine.Engine [cached since 0.2245s ago] ('2019-06-15', 4053, 409, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,433 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,434 INFO sqlalchemy.engine.Engine [cached since 0.2261s ago] ('2019-06-16', 4058, 410, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,435 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,435 INFO sqlalchemy.engine.Engine [cached since 0.2273s ago] ('2019-06-17', 4063, 414, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,436 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,436 INFO sqlalchemy.engine.Engine [cached since 0.2284s ago] ('2019-06-18', 4064, 417, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,437 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,437 INFO sqlalchemy.engine.Engine [cached since 0.2296s ago] ('2019-06-19', 4065, 422, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,438 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,439 INFO sqlalchemy.engine.Engine [cached since 0.2307s ago] ('2019-06-20', 4066, 424, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,439 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,440 INFO sqlalchemy.engine.Engine [cached since 0.2319s ago] ('2019-06-21', 4069, 425, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,440 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,441 INFO sqlalchemy.engine.Engine [cached since 0.233s ago] ('2019-06-22', 4070, 426, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,442 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,442 INFO sqlalchemy.engine.Engine [cached since 0.2342s ago] ('2019-06-23', 4073, 427, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,443 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,443 INFO sqlalchemy.engine.Engine [cached since 0.2354s ago] ('2019-06-24', 4084, 427, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,444 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,444 INFO sqlalchemy.engine.Engine [cached since 0.2365s ago] ('2019-06-25', 4108, 427, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,445 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,445 INFO sqlalchemy.engine.Engine [cached since 0.2375s ago] ('2019-06-26', 4122, 433, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,446 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,446 INFO sqlalchemy.engine.Engine [cached since 0.2387s ago] ('2019-06-27', 4132, 436, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,447 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,448 INFO sqlalchemy.engine.Engine [cached since 0.2402s ago] ('2019-06-28', 4150, 440, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,450 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,450 INFO sqlalchemy.engine.Engine [cached since 0.2425s ago] ('2019-06-29', 4162, 440, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,451 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,452 INFO sqlalchemy.engine.Engine [cached since 0.2442s ago] ('2019-06-30', 4164, 446, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,453 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,453 INFO sqlalchemy.engine.Engine [cached since 0.2455s ago] ('2019-07-01', 4167, 448, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,454 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,454 INFO sqlalchemy.engine.Engine [cached since 0.2467s ago] ('2019-07-02', 4174, 450, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,455 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,456 INFO sqlalchemy.engine.Engine [cached since 0.2478s ago] ('2019-07-03', 4179, 455, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,456 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,457 INFO sqlalchemy.engine.Engine [cached since 0.249s ago] ('2019-07-04', 4187, 456, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,457 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,458 INFO sqlalchemy.engine.Engine [cached since 0.2502s ago] ('2019-07-05', 4200, 456, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,459 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,459 INFO sqlalchemy.engine.Engine [cached since 0.2514s ago] ('2019-07-06', 4210, 458, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,460 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,460 INFO sqlalchemy.engine.Engine [cached since 0.2527s ago] ('2019-07-07', 4211, 458, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,461 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,462 INFO sqlalchemy.engine.Engine [cached since 0.254s ago] ('2019-07-08', 4214, 464, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,463 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,463 INFO sqlalchemy.engine.Engine [cached since 0.2555s ago] ('2019-07-09', 4219, 464, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,464 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,465 INFO sqlalchemy.engine.Engine [cached since 0.2575s ago] ('2019-07-10', 4223, 468, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,466 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,467 INFO sqlalchemy.engine.Engine [cached since 0.2587s ago] ('2019-07-11', 4228, 469, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,467 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,468 INFO sqlalchemy.engine.Engine [cached since 0.2599s ago] ('2019-07-12', 4236, 469, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,468 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:42,469 INFO sqlalchemy.engine.Engine [cached since 0.2612s ago] ('2019-07-13', 4239, 471, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:42,470 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# ...
# 2021-06-24 17:03:43,474 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,475 INFO sqlalchemy.engine.Engine [cached since 1.267s ago] ('2020-12-13', 10116, 1686, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,476 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,476 INFO sqlalchemy.engine.Engine [cached since 1.269s ago] ('2020-12-14', 10118, 1687, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,477 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,478 INFO sqlalchemy.engine.Engine [cached since 1.27s ago] ('2020-12-15', 10123, 1690, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,478 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,479 INFO sqlalchemy.engine.Engine [cached since 1.271s ago] ('2020-12-16', 10138, 1693, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,480 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,481 INFO sqlalchemy.engine.Engine [cached since 1.273s ago] ('2020-12-17', 10155, 1694, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,482 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,482 INFO sqlalchemy.engine.Engine [cached since 1.275s ago] ('2020-12-18', 10185, 1695, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,484 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,484 INFO sqlalchemy.engine.Engine [cached since 1.276s ago] ('2020-12-19', 10196, 1698, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,485 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,486 INFO sqlalchemy.engine.Engine [cached since 1.278s ago] ('2020-12-20', 10202, 1702, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,486 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,487 INFO sqlalchemy.engine.Engine [cached since 1.279s ago] ('2020-12-21', 10205, 1703, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,488 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,488 INFO sqlalchemy.engine.Engine [cached since 1.281s ago] ('2020-12-22', 10215, 1708, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,489 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,490 INFO sqlalchemy.engine.Engine [cached since 1.282s ago] ('2020-12-23', 10230, 1709, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,491 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,491 INFO sqlalchemy.engine.Engine [cached since 1.284s ago] ('2020-12-24', 10236, 1710, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,492 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,493 INFO sqlalchemy.engine.Engine [cached since 1.285s ago] ('2020-12-25', 10239, 1713, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,494 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,495 INFO sqlalchemy.engine.Engine [cached since 1.287s ago] ('2020-12-26', 10240, 1715, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,495 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,496 INFO sqlalchemy.engine.Engine [cached since 1.288s ago] ('2020-12-27', 10242, 1717, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,496 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,497 INFO sqlalchemy.engine.Engine [cached since 1.289s ago] ('2020-12-28', 10245, 1719, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,498 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,498 INFO sqlalchemy.engine.Engine [cached since 1.291s ago] ('2020-12-29', 10250, 1722, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,499 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,500 INFO sqlalchemy.engine.Engine [cached since 1.293s ago] ('2020-12-30', 10258, 1725, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,501 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,502 INFO sqlalchemy.engine.Engine [cached since 1.294s ago] ('2020-12-31', 10282, 1729, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,503 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,503 INFO sqlalchemy.engine.Engine [cached since 1.295s ago] ('2021-01-01', 10312, 1735, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,504 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,504 INFO sqlalchemy.engine.Engine [cached since 1.297s ago] ('2021-01-02', 10331, 1738, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,505 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,506 INFO sqlalchemy.engine.Engine [cached since 1.298s ago] ('2021-01-03', 10353, 1741, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,507 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,507 INFO sqlalchemy.engine.Engine [cached since 1.299s ago] ('2021-01-04', 10379, 1744, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,508 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,509 INFO sqlalchemy.engine.Engine [cached since 1.301s ago] ('2021-01-05', 10406, 1746, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,510 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,510 INFO sqlalchemy.engine.Engine [cached since 1.302s ago] ('2021-01-06', 10443, 1748, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,511 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,511 INFO sqlalchemy.engine.Engine [cached since 1.304s ago] ('2021-01-07', 10472, 1748, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,512 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,513 INFO sqlalchemy.engine.Engine [cached since 1.305s ago] ('2021-01-08', 10511, 1752, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,514 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,515 INFO sqlalchemy.engine.Engine [cached since 1.307s ago] ('2021-01-09', 10541, 1755, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,516 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,516 INFO sqlalchemy.engine.Engine [cached since 1.309s ago] ('2021-01-10', 10545, 1758, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,517 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,518 INFO sqlalchemy.engine.Engine [cached since 1.31s ago] ('2021-01-11', 10549, 1758, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,518 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,519 INFO sqlalchemy.engine.Engine [cached since 1.311s ago] ('2021-01-12', 10555, 1763, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,520 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,520 INFO sqlalchemy.engine.Engine [cached since 1.312s ago] ('2021-01-13', 10560, 1768, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,521 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,521 INFO sqlalchemy.engine.Engine [cached since 1.314s ago] ('2021-01-14', 10561, 1768, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,522 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,523 INFO sqlalchemy.engine.Engine [cached since 1.315s ago] ('2021-01-15', 10567, 1770, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,524 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,524 INFO sqlalchemy.engine.Engine [cached since 1.317s ago] ('2021-01-16', 10582, 1777, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,525 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,526 INFO sqlalchemy.engine.Engine [cached since 1.318s ago] ('2021-01-17', 10585, 1777, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,527 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,527 INFO sqlalchemy.engine.Engine [cached since 1.319s ago] ('2021-01-18', 10590, 1780, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,528 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,528 INFO sqlalchemy.engine.Engine [cached since 1.32s ago] ('2021-01-19', 10597, 1784, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,529 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,592 INFO sqlalchemy.engine.Engine [cached since 1.384s ago] ('2021-01-20', 10610, 1787, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,593 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,594 INFO sqlalchemy.engine.Engine [cached since 1.386s ago] ('2021-01-21', 10629, 1790, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,594 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,595 INFO sqlalchemy.engine.Engine [cached since 1.387s ago] ('2021-01-22', 10649, 1790, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,596 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,597 INFO sqlalchemy.engine.Engine [cached since 1.389s ago] ('2021-01-23', 10663, 1791, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,598 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,599 INFO sqlalchemy.engine.Engine [cached since 1.391s ago] ('2021-01-24', 10667, 1794, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,600 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,600 INFO sqlalchemy.engine.Engine [cached since 1.393s ago] ('2021-01-25', 10668, 1796, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,601 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,602 INFO sqlalchemy.engine.Engine [cached since 1.394s ago] ('2021-01-26', 10671, 1796, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,602 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,603 INFO sqlalchemy.engine.Engine [cached since 1.395s ago] ('2021-01-27', 10689, 1800, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,604 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,604 INFO sqlalchemy.engine.Engine [cached since 1.396s ago] ('2021-01-28', 10692, 1803, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,605 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,606 INFO sqlalchemy.engine.Engine [cached since 1.398s ago] ('2021-01-29', 10699, 1805, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,607 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,608 INFO sqlalchemy.engine.Engine [cached since 1.4s ago] ('2021-01-30', 10699, 1805, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,609 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,610 INFO sqlalchemy.engine.Engine [cached since 1.402s ago] ('2021-01-31', 10707, 1809, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,610 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,611 INFO sqlalchemy.engine.Engine [cached since 1.403s ago] ('2021-02-01', 10712, 1812, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,612 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,613 INFO sqlalchemy.engine.Engine [cached since 1.405s ago] ('2021-02-02', 10726, 1813, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,613 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,614 INFO sqlalchemy.engine.Engine [cached since 1.407s ago] ('2021-02-03', 10734, 1813, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,616 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,617 INFO sqlalchemy.engine.Engine [cached since 1.409s ago] ('2021-02-04', 10743, 1815, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,617 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,618 INFO sqlalchemy.engine.Engine [cached since 1.41s ago] ('2021-02-05', 10753, 1820, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,619 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,619 INFO sqlalchemy.engine.Engine [cached since 1.411s ago] ('2021-02-06', 10753, 1824, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,620 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,620 INFO sqlalchemy.engine.Engine [cached since 1.413s ago] ('2021-02-07', 10756, 1824, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,621 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,622 INFO sqlalchemy.engine.Engine [cached since 1.414s ago] ('2021-02-08', 10776, 1826, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,623 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2021-06-24 17:03:43,624 INFO sqlalchemy.engine.Engine [cached since 1.416s ago] ('2021-02-09', 10796, 1831, '2021-06-24 17:03:39.860078')
# 2021-06-24 17:03:43,630 INFO sqlalchemy.engine.Engine COMMIT

# %%
def read_data():
    from assets import models
    df = pd.read_csv('assets/data.csv')
    for index, _df in df.iterrows():
        #date型への変換
        date = datetime.datetime.strptime(_df['date'], '%Y/%m/%d').date()
        row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
        db_session.add(row)
    db_session.commit()
